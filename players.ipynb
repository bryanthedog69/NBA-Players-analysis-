# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/hp/Documents/python_files/Regular_Season.csv")
data.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0     year     Season_type  PLAYER_ID  RANK  \
# 0             0           0  2012-13  Regular_Season     201142     1
# 1             1           1  2012-13  Regular_Season        977     2
# 2             2           2  2012-13  Regular_Season       2544     3
# 3             3           3  2012-13  Regular_Season     201935     4
# 4             4           4  2012-13  Regular_Season       2546     5
#
#             PLAYER     TEAM_ID TEAM  GP  ...  DREB  REB  AST  STL  BLK  TOV  \
# 0     Kevin Durant  1610612760  OKC  81  ...   594  640  374  116  105  280
# 1      Kobe Bryant  1610612747  LAL  78  ...   367  433  469  106   25  287
# 2     LeBron James  1610612748  MIA  76  ...   513  610  551  129   67  226
# 3     James Harden  1610612745  HOU  78  ...   317  379  455  142   38  295
# 4  Carmelo Anthony  1610612752  NYK  67  ...   326  460  171   52   32  175
#
#     PF   PTS  AST_TOV  STL_TOV
# 0  143  2280     1.34     0.41
# ...

# %% [markdown]
# PERCENTAGE OF PLAYERS THAT PLAY FOR THE SAME TEAM

# %%
 #Group by TEAM and count unique players
team_player_count = data.groupby('TEAM')['PLAYER'].nunique()

# %%
#Calculate the percentage of players for each team 
team_player_percentage = (team_player_count / team_player_count.sum()) * 100

# %%
# Plotting the pie chart using Matplotlib directly
plt.figure(figsize=(10,8))
plt.pie(team_player_percentage, labels=team_player_percentage.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.tab20.colors)
plt.title('Percentage of players playing for the same team')
plt.show()
